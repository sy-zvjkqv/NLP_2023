# %%
import pandas as pd

# %%
df_test = pd.read_csv('/home/is/shuntaro-o/dev/persons_move_analysis/data/202271month_per_hour_geotaged_readGeocode_Tokyo.csv')

# %%
df_test
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0                 0        730977         754
# 1                 1        298539         758
# 2                 2        647662         557
# 3                 3         83175        1136
# 4                 4        601250        1098
# ...             ...           ...         ...
# 32318         32318        274786         727
# 32319         32319        392057        1052
# 32320         32320        981722        1033
# 32321         32321        486810        1430
# 32322         32322        376913        1299
#
#                                                     text           created_at  \
# 0                         上野着弾！！！https://t.co/TK2U1aVlUq  2022-07-22_14:54:26
# 1                    こんな時間におはようございます✨バタバタな1日…やっと落ち着けました😅  2022-07-09_19:56:58
# 2           ドンドン事実が出て来ますが事実は事実です。https://t.co/YQLd988CUG  2022-07-20_03:33:54
# 3                                                1週間前→現在  2022-07-03_10:55:12
# ...

# %%
import spacy
nlp = spacy.load("ja_core_news_md")

# %%
sentences = df_test.text.values
list_geo_Flag = []
for text in sentences:
    Flag = 0
    doc = nlp(text)
    for ent in doc.ents:
        if ent.label_=="GPE":
            Flag += 1
    #print(Flag)
    list_geo_Flag.append(Flag)

# %%
list_geo_Flag

# %%
list_geo_Flag=pd.Series(list_geo_Flag)
df_test=pd.concat([df_test,list_geo_Flag],axis=1)
df_test=df_test.rename(columns={0: 'Geo_Flag_multi'})

# %%
df_test[df_test['Geo_Flag_multi']==0]
