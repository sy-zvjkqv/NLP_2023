# %%
import pandas as pd

# %%
df_nation = pd.read_csv("df_test_Geoflag_multi.csv")

# %%
df_Tokyo = pd.read_csv('/home/is/shuntaro-o/dev/persons_move_analysis/data/202271month_per_hour_geotaged_readGeocode_Tokyo_adGeoFlag_multi.csv')

# %%
df_nation['Geo_Flag_multi'].unique()
# Out:
# array([ 0,  1,  2,  4,  3,  7,  6,  5, 14,  9,  8])

# %%
df_Tokyo['Geo_Flag_multi'].unique()
# Out:
# array([ 0,  1,  2,  3,  5,  4, 11,  7,  6])

# %%
df_nation_Geo_1 = df_nation[df_nation['Geo_Flag_multi']==1]

# %%
df_nation_Geo_over2 = df_nation[df_nation['Geo_Flag_multi']>=2]

# %%
df_Tokyo_Geo_1 = df_Tokyo[df_Tokyo['Geo_Flag_multi']==1]

# %%
df_Tokyo_Geo_over2 = df_Tokyo[df_Tokyo['Geo_Flag_multi']>=2]

# %%
df_nation_Geo_1
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 4                 4             4         297
# 23               23            23         812
# 25               25            25         523
# 28               28            28        1464
# 57               57            57         202
# ...             ...           ...         ...
# 65472         65472         65472         279
# 65480         65480         65480         339
# 65487         65487         65487        1116
# 65491         65491         65491         368
# 65503         65503         65503        1312
#
#                                                     text           created_at  \
# 4                      当券があるみたいなのでそろそろ難波寄ってから現場に向かいますか🚃🚃  2022-07-15_12:58:17
# 23                         大分に来たら待ち合わせは大分駅のあの場所に🤭#夜のイチスタ  2022-07-23_21:56:34
# 25     久々のデブの味方 (@ 飩餃 in Ayagawa Chō 香川県) https://t.c...  2022-07-16_14:57:31
# 28                       仕事終わったら某にドルパのガイドブック引き取りに行こう。(^^  2022-07-20_07:51:01
# ...

# %%
df_nation_Geo_1[df_nation_Geo_1['code']==df_nation_Geo_1['estimate_code']]
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 23               23            23         812
# 25               25            25         523
# 57               57            57         202
# 58               58            58         303
# 80               80            80         802
# ...             ...           ...         ...
# 65310         65310         65310         568
# 65349         65349         65349         113
# 65397         65397         65397         474
# 65419         65419         65419         200
# 65420         65420         65420        1408
#
#                                                     text           created_at  \
# 23                         大分に来たら待ち合わせは大分駅のあの場所に🤭#夜のイチスタ  2022-07-23_21:56:34
# 25     久々のデブの味方 (@ 飩餃 in Ayagawa Chō 香川県) https://t.c...  2022-07-16_14:57:31
# 57     【開催迄あと１０日】🥋参加無料・参加者特典有り🎁空手と柔道のハイブリッド❗めっちゃおもろい総...  2022-07-28_00:56:24
# 58     でっぱつ (@ JR 金山駅 - @jrcentral_ofl in 名古屋市 愛知県) h...  2022-07-30_05:56:18
# ...

# %%
df_nation_Geo_over2
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 5                 5             5        1211
# 14               14            14        1046
# 24               24            24         693
# 34               34            34        1194
# 43               43            43         317
# ...             ...           ...         ...
# 65354         65354         65354         883
# 65381         65381         65381        1370
# 65401         65401         65401         401
# 65430         65430         65430        1434
# 65459         65459         65459        1224
#
#                                                     text           created_at  \
# 5                       成田(千葉県) 02:00の気温 22.5℃ 南南東の風3m/s  2022-07-10_02:21:14
# 14     新潟(新潟県) 03:00の気温湿度 24.1℃ 95%RH (0.01801kg/kg(D...  2022-07-03_03:21:59
# 24     7月5日 #自民党 立候補者 #末松信介 街頭演説（加古川駅南口）その2#参院選 #参院選2...  2022-07-08_02:32:19
# 34                  高速道路走行中桜島がレベル5の噴火が起きたらしい今は宮崎県いるけど心配だ  2022-07-24_21:55:08
# ...

# %%
df_nation_Geo_over2[df_nation_Geo_over2['code']==df_nation_Geo_over2['estimate_code']]
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 5                 5             5        1211
# 14               14            14        1046
# 24               24            24         693
# 43               43            43         317
# 231             231           231         884
# ...             ...           ...         ...
# 65216         65216         65216        1171
# 65256         65256         65256         761
# 65300         65300         65300         780
# 65381         65381         65381        1370
# 65430         65430         65430        1434
#
#                                                     text           created_at  \
# 5                       成田(千葉県) 02:00の気温 22.5℃ 南南東の風3m/s  2022-07-10_02:21:14
# 14     新潟(新潟県) 03:00の気温湿度 24.1℃ 95%RH (0.01801kg/kg(D...  2022-07-03_03:21:59
# 24     7月5日 #自民党 立候補者 #末松信介 街頭演説（加古川駅南口）その2#参院選 #参院選2...  2022-07-08_02:32:19
# 43     家族揃って仲良くして下さってる十和田市で唯一のボクシングジムの会長さん（実はこの方めちゃくち...  2022-07-06_05:55:36
# ...

# %%
df_Tokyo_Geo_1
# Out:
#        Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 4                 4             4        601250        1098
# 6                 6             6        200274        1215
# 13               13            13        205089         257
# 27               27            27        346568         727
# 29               29            29        397957        1416
# ...             ...           ...           ...         ...
# 32257         32257         32257        323228          40
# 32259         32259         32259        564132         354
# 32283         32283         32283        798043         447
# 32284         32284         32284        146878        1365
# 32316         32316         32316        681998        1013
#
#                                                     text           created_at  \
# 4           I'matミルクスタジオin千代田区東京都https://t.co/F8Rj6F4bdl  2022-07-18_18:55:31
# 6         祝杯@みなと刺身専門店2号店in横浜市神奈川県https://t.co/ez92vleTVR  2022-07-06_21:54:20
# ...

# %%
df_Tokyo_Geo_1[df_Tokyo_Geo_1['Tokyo_code']==df_Tokyo_Geo_1['Tokyo_estimete_code']]
# Out:
#        Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 4                 4             4        601250        1098
# 6                 6             6        200274        1215
# 35               35            35        381304          77
# 61               61            61        797231        1048
# 65               65            65        465204        1024
# ...             ...           ...           ...         ...
# 32237         32237         32237        839725        1436
# 32257         32257         32257        323228          40
# 32259         32259         32259        564132         354
# 32283         32283         32283        798043         447
# 32316         32316         32316        681998        1013
#
#                                                     text           created_at  \
# 4           I'matミルクスタジオin千代田区東京都https://t.co/F8Rj6F4bdl  2022-07-18_18:55:31
# 6         祝杯@みなと刺身専門店2号店in横浜市神奈川県https://t.co/ez92vleTVR  2022-07-06_21:54:20
# ...

# %%
df_Tokyo_Geo_over2
# Out:
#        Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 18               18            18        559583        1332
# 31               31            31         56831         350
# 41               41            41        228317        1138
# 47               47            47        185299         131
# 205             205           205        738480        1321
# ...             ...           ...           ...         ...
# 32191         32191         32191        397802        1250
# 32196         32196         32196        294509         902
# 32200         32200         32200        773013         745
# 32225         32225         32225        948232        1343
# 32234         32234         32234        867929        1416
#
#                                                     text           created_at  \
# 18          I'mat7-8番線ホームin立川市東京都https://t.co/Piwd2UCVik  2022-07-17_12:54:47
# 31     今日はここから。いやぁ、思ったより風が通ってて、それ程不快じゃないかも。#fctokyo#t...  2022-07-02_16:58:41
# ...

# %%
df_Tokyo_Geo_over2[df_Tokyo_Geo_over2['Tokyo_code']==df_Tokyo_Geo_over2['Tokyo_estimete_code']]
# Out:
#        Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 18               18            18        559583        1332
# 31               31            31         56831         350
# 41               41            41        228317        1138
# 47               47            47        185299         131
# 205             205           205        738480        1321
# ...             ...           ...           ...         ...
# 32063         32063         32063        500753         123
# 32196         32196         32196        294509         902
# 32200         32200         32200        773013         745
# 32225         32225         32225        948232        1343
# 32234         32234         32234        867929        1416
#
#                                                     text           created_at  \
# 18          I'mat7-8番線ホームin立川市東京都https://t.co/Piwd2UCVik  2022-07-17_12:54:47
# 31     今日はここから。いやぁ、思ったより風が通ってて、それ程不快じゃないかも。#fctokyo#t...  2022-07-02_16:58:41
# ...

# %%
df_nation_Geo_over2
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 5                 5             5        1211
# 14               14            14        1046
# 24               24            24         693
# 34               34            34        1194
# 43               43            43         317
# ...             ...           ...         ...
# 65354         65354         65354         883
# 65381         65381         65381        1370
# 65401         65401         65401         401
# 65430         65430         65430        1434
# 65459         65459         65459        1224
#
#                                                     text           created_at  \
# 5                       成田(千葉県) 02:00の気温 22.5℃ 南南東の風3m/s  2022-07-10_02:21:14
# 14     新潟(新潟県) 03:00の気温湿度 24.1℃ 95%RH (0.01801kg/kg(D...  2022-07-03_03:21:59
# 24     7月5日 #自民党 立候補者 #末松信介 街頭演説（加古川駅南口）その2#参院選 #参院選2...  2022-07-08_02:32:19
# 34                  高速道路走行中桜島がレベル5の噴火が起きたらしい今は宮崎県いるけど心配だ  2022-07-24_21:55:08
# ...

# %%
import spacy
nlp = spacy.load("ja_core_news_md")
list_ent = []
bun = ''
sentences = df_nation_Geo_over2.text.values
list_ent_list = []
for text in sentences:
    Flag = 0
    doc = nlp(text)
    bun = ''
    for ent in doc.ents:
        if ent.label_=="GPE":
            bun += str(ent)+ ','
    list_ent.append([bun])
    #print(Flag)
    #list_geo_Flag.append(Flag)
# Out:
# 2023-01-11 17:01:38.688318: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-01-11 17:01:38.688347: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# セル19 を /home/is/shuntaro-o/dev/persons_move_analysis/notebooks/use_new_model/multi_geo_analysis.ipynb in <cell line: 7>()
# ...

# %%
list_ent
# Out:
# 0            [成田千葉県]
# 1            [新潟新潟県]
# 2       [兵庫県選挙区加古川市]
# 3            [桜島宮崎県]
# 4           [十和田市青森]
#             ...
# 2087      [坂井市東尋坊福井]
# 2088          [札幌石狩]
# 2089      [沖縄大阪高槻沖縄]
# 2090        [今治市今治市]
# 2091       [多賀城市女川町]
# Length: 2092, dtype: object

# %%
df_nation
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0                 0             0         937
# 1                 1             1         876
# 2                 2             2         260
# 3                 3             3        1174
# 4                 4             4         297
# ...             ...           ...         ...
# 65499         65499         65499        1039
# 65500         65500         65500        1364
# 65501         65501         65501        1403
# 65502         65502         65502        1309
# 65503         65503         65503        1312
#
#                                                     text           created_at  \
# 0      サントリー白州蒸溜所ツアー樽貯蔵庫に足を踏み入れた瞬間の香り…忘れられない🥃何度でも訪れたい...  2022-07-12_13:52:40
# 1      ここ最近購入した目覚まし時計を譲る事となりました。中古品ですが、ナショナルクロックラジオ「簡...  2022-07-26_22:54:46
# 2                  ここでも35℃ #35Do https://t.co/Rp42XHmLDS  2022-07-01_10:58:09
# 3                       @JirouAruma たぶんそうですよね♪店構えに出るし(笑)  2022-07-30_07:53:09
# ...

# %%
list_ent=pd.Series(list_ent)
df_nation_Geo_over2 = df_nation_Geo_over2.reset_index(drop=True)
df_nation_Geo_over2_adGeotext=pd.concat([df_nation_Geo_over2,list_ent],axis=1)
df_nation_Geo_over2_adGeotext=df_nation_Geo_over2_adGeotext.rename(columns={0: 'bun'})

# %%
df_nation_Geo_over2_adGeotext[df_nation_Geo_over2_adGeotext['code']==df_nation_Geo_over2_adGeotext['estimate_code']].to_csv('T_tmp.csv')

# %%
text = '当券があるみたいなのでそろそろ難波寄ってから現場に向かいますか'
doc = nlp(text)
for ent in doc.ents:
    print(ent.label_)
    print(ent)
# Out:
# GPE
# 難波
